# %%
# get key
import pandas as pd

keys = pd.read_csv("keys/keys_hezhang.csv", index_col=0)
openai_key = keys.loc["openai", "key_value"]

# %%
import openai
openai.api_type = "azure"
openai.api_base = "https://explore-openai.openai.azure.com/"
openai.api_version = "2022-12-01"
openai.api_key = openai_key

model = "text-davinci-003"

# %%
from IPython.display import Image

# %% [markdown]
# ## 1. Passenger Name Record (PNR)

# %%
Image(filename="data/pnr_data_intro_wiki.png")

# %% [markdown]
# ## 2. Understand PNR Data

# %%
prompt = """
         An example Passenger Name Record (PNR) data below:
         
         ###
         MU99XZ
         1EZRRK1/22FEB2E2/SGN
         DL/KE/AF/SQ
         LAXLHR/AF/LHRJNB/DL/JNBJFK/SQ
         22FEB22/28FEB22
         1/2
         SMITH/JOHNM
         987654321
         DL 23 Y 22FEB 2 LAXLHR HK1 1025A 545P 1A/E
         AF 168 Y 22FEB 2 LHRJNB HK1 930P 955A 1A/E
         DL 54 Y 25FEB 5 JNBJFK HK1 1240A 610A 1A/E
         SQ 238 Y 26FEB 6 JFKSIN HK1 1050A 525P 1A/E
         SQ 186 Y 26FEB 6 SGNBKK HK1 820P 1000P 1A/E
         KE 652 Y 28FEB 1 BKKICN HK1 1215A 720P 1A/E
         KE 601 Y 28FEB 1 ICNLAX HK1 1000P 540P 1A/E
         E-TKT 0123456789ABCDEF
         ###
         
         Summarize the PNR data.
         """

# openai results
response=openai.Completion.create(
    engine=model,
    prompt=prompt,
    temperature=1,
    max_tokens=1000,
    top_p=1,
    frequency_penalty=0.5,
    presence_penalty=0.5)
print(response["choices"][0]["text"].replace("\n", ""))
# Out:
#          The Passenger Name Record (PNR) data contains the flight details for a passenger named John Smith. The itinerary includes six flights of various airlines and dates, beginning on February 22nd in Los Angeles and ending on February 28th in Los Angeles. There is also a unique e-ticket number provided for this traveler.

# %%
prompt = """
         An example Passenger Name Record (PNR) data below:
         
         ###
         MU99XZ
         1EZRRK1/22FEB2E2/SGN
         DL/KE/AF/SQ
         LAXLHR/AF/LHRJNB/DL/JNBJFK/SQ
         22FEB22/28FEB22
         1/2
         SMITH/JOHNM
         987654321
         DL 23 Y 22FEB 2 LAXLHR HK1 1025A 545P 1A/E
         AF 168 Y 22FEB 2 LHRJNB HK1 930P 955A 1A/E
         DL 54 Y 25FEB 5 JNBJFK HK1 1240A 610A 1A/E
         SQ 238 Y 26FEB 6 JFKSIN HK1 1050A 525P 1A/E
         SQ 186 Y 26FEB 6 SGNBKK HK1 820P 1000P 1A/E
         KE 652 Y 28FEB 1 BKKICN HK1 1215A 720P 1A/E
         KE 601 Y 28FEB 1 ICNLAX HK1 1000P 540P 1A/E
         E-TKT 0123456789ABCDEF
         ###
         
         Summarize the PNR data, in simplified Chinese language.
         """

# openai results
response=openai.Completion.create(
    engine=model,
    prompt=prompt,
    temperature=1,
    max_tokens=1000,
    top_p=1,
    frequency_penalty=0.5,
    presence_penalty=0.5)
print(response["choices"][0]["text"].replace("\n", ""))
# Out:
#          本PNR数据表明，John Smith拥有一张航班号为MU99XZ的电子客票，从洛杉矶机场出发（22FEB2E2/SGN），先乘坐达美航空前往伦敦希斯罗机场（LAXLHR/AF/LHRJNB/DL/JNBJFK/SQ ）、再乘坐达美航空前往约翰·斯坦尼斯机场（22FEB22/28FEB22 ）、之后乘坐新加坡航空前往新加坡机场（JFKSIN HK1 1050A 525P 1A / E ）、最后乘坐韩亚航空飞往香港国际机场（SGNBKK HK1 820P 1000P 1A / E ）以及回到洛杉矶机场。

# %%
prompt = """
         An example Passenger Name Record (PNR) data below:
         
         ###
         MU99XZ
         1EZRRK1/22FEB2E2/SGN
         DL/KE/AF/SQ
         LAXLHR/AF/LHRJNB/DL/JNBJFK/SQ
         22FEB22/28FEB22
         1/2
         SMITH/JOHNM
         987654321
         DL 23 Y 22FEB 2 LAXLHR HK1 1025A 545P 1A/E
         AF 168 Y 22FEB 2 LHRJNB HK1 930P 955A 1A/E
         DL 54 Y 25FEB 5 JNBJFK HK1 1240A 610A 1A/E
         SQ 238 Y 26FEB 6 JFKSIN HK1 1050A 525P 1A/E
         SQ 186 Y 26FEB 6 SGNBKK HK1 820P 1000P 1A/E
         KE 652 Y 28FEB 1 BKKICN HK1 1215A 720P 1A/E
         KE 601 Y 28FEB 1 ICNLAX HK1 1000P 540P 1A/E
         E-TKT 0123456789ABCDEF
         ###
         
         List other industries, one by one, using similar coding system 
         as PNR to represent actions or transactions.
         """

# openai results
response=openai.Completion.create(
    engine=model,
    prompt=prompt,
    temperature=0,
    max_tokens=1000,
    top_p=1,
    frequency_penalty=0.5,
    presence_penalty=0.5)
print(response["choices"][0]["text"].replace("\n", ""))
# Out:
#          1. Banking: Using a coding system to represent financial transactions such as deposits, withdrawals, transfers, and payments.                  2. Retail: Using a coding system to represent purchases, returns, exchanges, and discounts.                  3. Healthcare: Using a coding system to represent medical procedures, treatments, medications, and insurance claims.                  4. Education: Using a coding system to represent student enrollments, course registrations, grades, and transcripts.                   5. Logistics: Using a coding system to represent shipments, deliveries, tracking numbers, and freight costs.

# %%
prompt = """
         An example SWIFT message from Banking Industry as below:
         
         ###        
         {1:F01KNABNL2HAXXX0000000000}
         {2:1940KNABNL2HXXXXN3020}
         {4: :20:B4G30MS9D00A003D :25:123456789 :28C:999/1 :60F:C140729EUR3058,
         98 :61:1407290729D2760,NTRFNONREF//B4G29PGCVO7Q06US /OCMT/EUR10,
         00/ :86:FACTUUR 201403110, 201403113 REK: NL65INGB0123456789/NAAM: 
         PICQER :61:1407290729C500NTRF29-07-2014 10:05//B4G29PGDCK1QFV3E 
         :86:12160475 0050001631430920 ORDERID: 264267 MEDIA MARKT ONLINE NE REK: 
         NL84INGB0234561789/NAAM: MMS ONLINE NEDERLAND B.V. :62F:C140730EUR798,98 
         -}
         ###
         
         Tasks:
         1. Summarize the above SWIFT message.
         2. Determine the risk level in [low, medium, high] 
         in terms of Fraud Detection or Money Laundering, and briefly give reasons.
         
         Answer above questions one at a time.
         """

# openai results
response=openai.Completion.create(
    engine=model,
    prompt=prompt,
    temperature=1,
    max_tokens=1000,
    top_p=1,
    frequency_penalty=0.5,
    presence_penalty=0.5)
print(response["choices"][0]["text"].replace("\n", ""))
# Out:
#          1.          The above SWIFT message refers to two transactions that involve the transfer of money from KNABNL2HAXXX (Account Holder) to PICQER and MMS ONLINE NEDERLAND B.V (Recipient). Both transfers are in the currency EUR with an amount of 3058,98 and 798,98 respectively. Along with the final amount field, there is a field containing additional information such as FACTUUR numbers, Transaction Ids and other relevant details related to the transactions.                  2.          The risk level for these transactions is low as there are sufficient details provided in order identify both parties involved and all other necessary details regarding the payment made - such as receipt number or invoice number. All these data points can be verified which makes it difficult for fraudsters or money launderers to carry out their activities.

# %%
prompt = """
         An example SWIFT message from Banking Industry as below:
         
         ###        
         {1:F01KNABNL2HAXXX0000000000}
         {2:1940KNABNL2HXXXXN3020}
         {4: :20:B4G30MS9D00A003D :25:123456789 :28C:999/1 :60F:C140729EUR3058,98 :61:1407290729D2760,NTRFNONREF//B4G29PGCVO7Q06US /OCMT/EUR10,00/ :86:FACTUUR 201403110, 201403113 REK: NL65INGB0123456789/NAAM: PICQER :61:1407290729C500NTRF29-07-2014 10:05//B4G29PGDCK1QFV3E :86:12160475 0050001631430920 ORDERID: 264267 MEDIA MARKT ONLINE NE REK: NL84INGB0234561789/NAAM: MMS ONLINE NEDERLAND B.V. :62F:C140730EUR798,98 
         -}
         ###
         
         Tasks:
         1. Summarize the above SWIFT message.
         2. Determine the risk level in [low, medium, high] 
         in terms of Fraud Detection or Money Laundering, and briefly give reasons.
         
         Answer above questions one at a time, in simplified Chinese language.
         """

# openai results
response=openai.Completion.create(
    engine=model,
    prompt=prompt,
    temperature=1,
    max_tokens=1000,
    top_p=1,
    frequency_penalty=0.5,
    presence_penalty=0.5)
print(response["choices"][0]["text"].replace("\n", ""))
# Out:
#          1. 以上SWIFT消息主要描述了一笔金钱从账户NL65INGB0123456789中到账户NL84INGB0234561789，金额为3058.98 EUR和798.98 EUR。          2. 在欺诈检测和反洗钱方面，风险水平是低的。原因是此消息似乎正常而无异常的情况，而且有明确的客户、账号、日期等信息来证实交易的合法性。
